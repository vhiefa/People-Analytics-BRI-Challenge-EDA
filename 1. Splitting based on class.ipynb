# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('./0.train.csv')
df_train.head()
# Out:
#   job_level  job_duration_in_current_job_level person_level  \
# 0      JG04                           1.352775         PG03
# 1      JG04                           1.292285         PG03
# 2      JG05                           2.565151         PG06
# 3      JG05                           2.828427         PG06
# 4      JG05                           2.828427         PG06
#
#    job_duration_in_current_person_level  job_duration_in_current_branch  \
# 0                              1.352775                        1.732051
# 1                              1.292285                        1.039230
# 2                              2.308679                        1.780449
# 3                              1.000000                        1.385641
# 4                              2.828427                        0.707107
#
#   Employee_type  gender   age marital_status_maried(Y/N)  \
# 0     RM_type_A       2  1985                          Y
# ...

# %%
neg, pos = np.bincount(df_train['Best Performance'].to_numpy())
print("negative class :", neg)
print("positive class :", pos)
print("total :", neg + pos)
# Out:
# negative class : 9516
# positive class : 1637
# total : 11153

# %% [markdown]
# # Split positive and negative class

# %%
by_class = df_train.groupby('Best Performance')

# %%
df_train_positive = by_class.get_group(1)
df_train_negative = by_class.get_group(0)

# %%
print(df_train_positive.shape)
print(df_train_negative.shape)
# Out:
# (1637, 22)
# (9516, 22)

# %%
df_train_positive.to_csv("1.train_positive.csv", index=False)
df_train_negative.to_csv("1.train_negative.csv", index=False)
